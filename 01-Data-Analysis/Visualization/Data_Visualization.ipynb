# %% [markdown]
# # **Visualizing distributions**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **A plot tells a thousand words**

# %% [markdown]
# "A plot tells a thousand words"
#
# 🎯 الفكرة:
#
# الرسم مش خطوة تجميلية، بل خطوة تحليلية، تكشف ما لا تراه في الأرقام.
#
# 📌 3. ثلاث طرق لفهم البيانات
#
# الإحصاء الوصفي: زي المتوسط والوسيط والانحراف المعياري
#
# النماذج الإحصائية: زي الانحدار (linear regression)
#
# الرؤية البصرية: الرسم البياني – وده اللي هنتعلمه هنا
#
# ✅ التلاتة مهمين، لكن الرسم هو أسرع وسيلة توصلك لفهم أولي وشامل للبيانات.

# %% [markdown]
# قبل ما تبدأ ترسم، لازم تسأل:
#
# هل بياناتي "مستمرة" ولا "تصنيفية"؟
#
# 🧮 Continuous Variables (متغيرات مستمرة)
#
# أرقام يمكن جمعها وطرحها
#
# أمثلة: الطول – الوزن – السعر – الوقت
#
# 🏷️ Categorical Variables (تصنيفية)
#
# قيم تمثل "فئة" مش قيمة عددية
#
# أمثلة: لون – بلد – نوع منتج – فئة عمرية

# %% [markdown]
# ## Histogram

# %% [markdown]
# الهستوجرام هو نوع من الرسومات البيانية المستخدمة لعرض توزيع متغير عددي (continuous) بشكل بصري.
#
# 🎯 Histogram يُستخدم عندما:
# يكون عندك متغير عددي واحد فقط
#
# وعايز تعرف:
#
# قيمته الدنيا والعليا
#
# أكثر القيم شيوعًا
#
# شكل التوزيع (هل فيه نمط واضح؟ هل القيم مركزة؟)
#
# 📌 باختصار: الهستوجرام بيجاوب على سؤال:
#
# "البيانات دي بتتوزع إزاي؟"

# %% [markdown]
# 📌 5. أهمية عرض bin width بدقة
#
# Bin واسع = تفقد التفاصيل
#
# Bin ضيق = تبقى مزعجة ومضللة

# %% [markdown]
# 📌 6. Modality (عدد القمم)
#
# 1 قمة → Unimodal
#
# 2 قمم → Bimodal
#
# 3 أو أكثر → Multimodal

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 143807.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📌 7. Skewness (الانحراف)
#
# لو البيانات متوزعة بالتساوي حوالين المنتصف → Symmetric
#
# لو الذيل ناحية اليسار + Outliers منخفضة → Left-skewed
#
# لو الذيل ناحية اليمين + Outliers مرتفعة → Right-skewed

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 143840.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# عنصر متقدم: Kurtosis  📌
#
# Kurtosis = عدد وشدة القيم الشاذة (outliers)
#
# Mesokurtic	Bell shape	زي التوزيع الطبيعي
#
# Leptokurtic	قمة ضيقة جدًا	كثير من القيم الشاذة (مثلًا في البورصة)
#
# Platykurtic	قمة عريضة	قليل من القيم الشاذة

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 143938.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Box Plots

# %% [markdown]
# 📌 1. ليه نحتاج بديل للهستوجرام؟
#
# الهستوجرام ممتاز… لكن لما يكون عندك عدة مجموعات
#
# وتحاول ترسم لكل مجموعة Histogram، النتيجة بتكون فوضى بصرية.

# %% [markdown]
# Histogram vs Box Plot
#
# __:النوع	 الوصف     	مساحة الاستخدام __	مقارنة مجموعات  __
#
# Histogram:__	شكل التوزيع بالتفصيل 	   كبيرة   __ 	صعب __
#
# Box Plot:__	إحصائيات التوزيع + Outliers	صغيرة __ 	 ممتاز  __

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# تحميل الصورة
img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Screenshots\Screenshot 2025-07-10 064825.png")

# عرض الصورة
plt.imshow(img)
plt.axis('off')  # لإخفاء الإحداثيات
plt.show()

# %% [markdown]
# # **Visualizing two variables**

# %% [markdown]
# ## **Scatter plots**

# %% [markdown]
# 📌 2. إمتى تستخدم Scatter Plot
#
# لو عندك 2 متغيرات رقمية (continuous)
#
# 📊 Scatter plot يساعدك تجاوب على:
#
# لما المتغير الأول يزيد، التاني بيزيد ولا بيقل؟ ولا مفيش علاقة خالص؟

# %% [markdown]
# أول محاولة رسم:
#
# X-axis: المساحة
#
# Y-axis: السعر
#
# لكن النتيجة: كل النقط متكدسة في الركن الشمال تحت → صعب القراءة 👀

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 145355.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 💡 الحل:
#
# نستخدم logarithmic scale (مقياس لوغاريتمي) على المحورين

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 145543.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📉 5. مفهوم مهم: الـ Correlation (الارتباط)
#
# الـ Correlation بيقيس مدى "الخطّية" في العلاقة بين المتغيرين

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 145621.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🦕 6. لكن خلي بالك… أحيانًا الـ Correlation يخدعك
#
# رجعنا للـ Datasaurus Dozen
#
# كل الرسومات ليها نفس المتوسط والانحراف المعياري والـ correlation
#
# لكن أشكالها مختلفة (ديناصور، نجمة، دائرة…)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 150139.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📏 7. إضافة Trend Line (خط الاتجاه)
#
# لو عايز تشوف هل فيه علاقة خطّية فعلاً ولا لأ:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 150331.png")

plt.imshow(img)

plt.axis('off')
plt.show()

# %%
img1 = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 150432.png")

plt.imshow(img1)

plt.axis('off')
plt.show()

# %% [markdown]
# ## **Line Plots**

# %% [markdown]
# 🧭 1. إيه هو Line Plot؟
#
# الـ Line Plot هو قريب جدًا من الـ scatter plot
#
# لكن الفرق الأساسي: النقط مترتبة ومتصلة بخطوط

# %% [markdown]
# الرسم الأول كان مجرد scatter plot
#
# لكن:
#
# لأن الـ x-axis عبارة عن تواريخ (تسلسل زمني)
#
# والنقط المفروض تكون متصلة ببعض
#
# 📈 إذًا الحل الأفضل: Line plot علشان يوضح الزيادة المستمرة في عدد الحالات

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 153307.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# Line plot يُستخدم في نفس الحالات اللي نستخدم فيها scatter plot،
# بس بشرط إضافي:
#
# "النقاط متصلة منطقيًا أو زمنيًا ببعض"
#
# أشهر حالة:
#
# الـ x-axis يمثل الوقت أو التاريخ
#
# بس ممكن تكون كمان أي حاجة مترتبة بشكل منطقي

# %% [markdown]
# 📊 4. مقارنة عدة خطوط مع بعض
#
# واحدة من أقوى مميزات line plots إنك ممكن تعرض أكتر من خط في نفس الرسم
#
# وتقدر تقارن الاتجاهات بسهولة

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 154630.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📐 5. Trend Lines (خطوط الاتجاه)
#
# أحيانًا بنرسم خط مستقيم بسيط عشان يقرب الاتجاه العام (باستخدام linear regression)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 154654.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 💡 لكن لما استخدمنا logarithmic scale على محور y
#
# الخط المستقيم بقى مناسب، لأن:
#
# البيانات بتزيد بشكل أُسّي (exponential) مش خطّي!

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 154758.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ⚠️ 7. هل وجود time على x-axis يعني Line Plot دايمًا؟
#
# لا! ✋ مش كل ما يكون المحور الأفقي وقت يبقى لازم نستخدم line plot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 154854.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🔄 9. مش لازم x-axis يكون وقت!

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 155005.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Bar Plots**

# %% [markdown]
# 🧭 1. إيه هو Bar Plot؟
#
# Bar plots قريبين في الشكل من box plots
#
# لكن الهدف مختلف: عرض قيمة واحدة لكل فئة (Category)
#
# سواء كانت عدد (count) أو نسبة مئوية (percentage) أو متوسط أو غيره

# %% [markdown]
# 📌 2. إمتى تستخدم Bar Plot؟
#
# Bar plots مناسبة لما يكون عندك:
#
# متغير تصنيفي (categorical) مثل: الدولة، الجنس، النوع
#
# وعايز تشوف:
#
# كم مرة ظهر؟
#
# أو كم نسبته؟
#
# أو أي مقياس واحد يلخصه
#
# 🎯 شرط مهم:
#
# الصفر لازم يكون ليه معنى حقيقي، لأن الأعمدة بتمتد من الصفر للقيمة.

# %% [markdown]
# 🇺🇸 5. رسم الأعمدة حسب الدولة
#
# الفئات = الدول (على المحور العمودي)
#
# القيم = عدد الرياضيين من كل دولة (على المحور الأفقي)
#
# ده اسمه horizontal bar plot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 220734.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🔄 6. طيب لو قلبنا المحاور؟
#
# ممكن تعمل نفس الرسم بشكل عمودي (vertical)
#
# بس ده بيخلي قراءة أسماء الدول صعب (هتضطر تميل راسك 😅)
#
# 🔁 الحل الأفضل: خليك في horizontal في الحالة دي.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 220759.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📈 7. الترتيب مهم!
#
# رتّب الأعمدة من الأكبر للأصغر
#
# ده بيخلي المقارنة أسهل، ويخليك تشوف بسرعة إن مثلاً:
#
# إسبانيا والهند متساويين في المركز الخامس (كل واحدة فيها 4 رياضيين)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 220824.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🧱 9. الأعمدة المجمعة (Stacked Bar Plot)
#
# لما المجموع دائمًا = 100%، يبقى منطقي نستخدم الأعمدة المجمعة
# مثال:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 221033.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📊 10. الفرق بين Bar Plot و Box Plot؟
#
# Bar Plot
#
# يعرض قيمة واحدة لكل فئة (مثلاً: العدد)
#
# يستخدم لمقارنة المقادير
#
# Box Plot
#
# يعرض توزيع قيم متغير مستمر في كل فئة
#
# يستخدم لفهم الانتشار والتشتت

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 221317.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🔢 11. مش لازم Count فقط
#
# ممكن تستخدم bar plot لعرض:
#
# المتوسط
#
# النسبة
#
# المجموع
#
# مثال: متوسط عمر بدء الحكم للملوك حسب العائلة الملكية
#
# 🟨 ملاحظة: الرسم صحيح، لكن أقل إثارة من box plot اللي بيعرض كامل التوزيع

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-10 221455.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ##  **Dot Plot**

# %% [markdown]
# 🧭 1. ما هو Dot Plot؟
#
# هو نوع من الرسوم البيانية المشابهة جدًا لـ bar plots
#
# لكن بدل ما بنرسم عمود لكل فئة،
#
# 🔘 بنحط نقطة واحدة فقط تمثل القيمة.

# %% [markdown]
# ❓ 2. إمتى تستخدم Dot Plot؟
#
# بنستخدم dot plots في نفس الحالات اللي بنستخدم فيها bar plots،
# لكن فيه ميزتين بيخلوه يتفوق أحيانًا:
#
# ممكن تستخدم مقياس لوغاريتمي (log scale)
#
# ➕ bar plots مش بيدعم ده لأن الأشرطة تبدأ من صفر
#
# ممكن تعرض أكتر من مقياس (metric) لكل فئة
#
# ➜ يعني مقارنة أوزان، مسافات، متوسطات... كلها في رسم واحد!

# %% [markdown]
# 🌌 3. النجوم القريبة والأقزام البنية
#
# البيانات هنا عن النجوم الأقرب للأرض
#
# المسافة: بالسنوات الضوئية
#
# الكتلة: بوحدة "كتلة الشمس" (Solar Masses)

# %% [markdown]
# 📊 4. Bar Plot vs. Dot Plot
#
# لو استخدمنا bar plot لعرض كتلة النجوم:
#
# بعض الأعمدة طويلة جدًا (نجوم ضخمة)
#
# وبعضها صغير جدًا (صعب تشوفه أصلاً)
#
# 🤔 المشكلة: فيه فرق ضخم بين القيم، فالرسم مش متوازن
#
# ✅ الحل؟ نستخدم مقياس لوغاريتمي (log scale)
#
# ❌ لكن ده مش متاح في bar plot لأن:
#
# "اللوغاريتم لـ 0 = -∞"، و الأعمدة لازم تبدأ من 0
#
# 🟢 Dot Plot يحل المشكلة:
#
# كل نقطة تمثل القيمة
#
# وتقدر تستخدم معاها log scale
#
# بالتالي: الرسم هيظهر القيم الصغيرة والكبيرة بوضوح

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 002407.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 📏 5. استخدام الـ Log Scale
#
# المقياس اللوغاريتمي مفيد جدًا لما يكون السؤال:
#
# "النجم ده أكبر كام مرة من النجم التاني؟"
#
# يعني بنفكر في نسبة مضاعفة مش فرق عددي مباشر

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 002442.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🔃 6. ترتيب الصفوف
#
# زي الـ bar plots، ترتيب الفئات مهم جدًا
#
# لو رتبنا النجوم من الأكبر للأصغر،
#
# 📍 هيسهل علينا نجاوب أسئلة زي:
#
# "مين أثقل نجم؟"
#
# "مين الأخف نجم قريب من الأرض؟"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 002524.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # **The Color and the Shape**

# %% [markdown]
# ##  **Higher Dimensions**

# %% [markdown]
# 🚀 1. Higher Dimensions – أكتر من بعدين؟
#
# لحد دلوقتي كنت بترسم متغير واحد (زي histogram) أو اتنين (زي scatter plot).
#
# لكن البيانات الواقعية غالبًا بيكون فيها أكتر من متغيرين، طيب نعمل إيه؟ 🤔

# %% [markdown]
# 🌍 2. UN Life Expectancy Scatter Plots
#
# مثال من الأمم المتحدة:
#
# بدل ما ترسم العلاقة بين العمر المتوقع (Life Expectancy) وطول التعليم فقط،
#
# أو بين العمر المتوقع والدخل فقط (GNI)،
#
# ليه ما ترسم التأثير المشترك للتعليم + الدخل مع بعض على العمر المتوقع؟ 💡

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 005325.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🧱 3. 3D Scatter Plots – فخ الرسومات الثلاثية
#
# الناس أول ما تسمع "3 متغيرات" تفكر فورًا في 3D scatter plot
# لكن في الحقيقة، على شاشة 2D، الشكل بيبقى مش واضح نهائي.
#
# ❌ بيضيع العمق
#
# ❌ زوايا الكاميرا مش مفهومة
#
# ❌ صعب تفسره

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 005607.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🔁 4. أبعاد غير x و y؟ أه طبعًا!
#
# بدل ما تزود محور جديد، ممكن تمثل أبعاد إضافية عبر خصائص النقاط:
#
# 🎨 اللون (color)	مقياس كمي أو تصنيفي  _____
#
# 🔵 الحجم (size)	قيمة رقمية (كل ما تكبر القيمة تكبر النقطة)____
#
# 🌫️ الشفافية (transparency)	درجة الانتباه للنقطة____
#
# 🧩 الشكل (shape)	فئة أو مجموعة محددة

# %% [markdown]
# ### 🎨 5. اللون – Color

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 005748.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🔵 6. الحجم – Size

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 005844.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🌫️ 7. الشفافية – Transparency

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 005929.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🧩 8. الشكل – Shape

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 005951.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 📦 9. الرسم في Panels

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 010052.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🔍 10. Panels أكثر دقة

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 010153.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 📈 11. أبعاد إضافية في Line Plots؟ أكيد

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 010301.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### ⚙️ 13. نوع الخط – Linetype

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 010320.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Using Color**

# %% [markdown]
# اللون هو أقوى أداة لتمييز القيم بصريًا. بس عشان تستخدمه صح، لازم تختار الألوان بعناية مش بشكل عشوائي.

# %% [markdown]
# 🌈 2. ألوان RGB – Red-Green-Blue
#
# في البرمجة (زي Python وMatplotlib)، بنمثل الألوان بمقدار:
#
# أحمر (Red)
#
# أخضر (Green)
#
# أزرق (Blue)
#
# يعني كل لون هو مزيج من التلاتة دول → ده اسمه RGB colorspace

# %% [markdown]
# 📉 4. مشكلة اختيار ألوان سيئة
#
# مثال عملي:
#
# لو رسمت أسعار بيوت بلوس أنجلوس بمجموعة ألوان، ممكن تكون بعض الألوان:
#
# ✖️ باهتة (زي الأصفر)، فالعين تتجاهلها
#
# ✖️ متشابهة (زي الأزرق والبنفسجي)، فتتلخبط
#
# 👎 ده ممكن يخلي القارئ يفسر الرسمة غلط

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 110016.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🧪 5. نظام HCL – الأفضل للتصور البياني
#
# العلماء طوروا نظام خاص للبيانات اسمه Hue-Chroma-Luminance (HCL):
#
# Hue	اللون (زي أحمر، أخضر، أزرق...)
#
# Chroma	شدة اللون – من رمادي باهت إلى لون فاقع
#
# Luminance	الإضاءة – من أسود إلى أبيض

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 110308.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🧩 8. 3 أنواع من مقاييس الألوان – Color Scales

# %% [markdown]
# #### 🎨 Qualitative	للتصنيفات غير المرتبة (زي الأكلات أو الدول)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 110423.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# #### 📈 Sequential	للبيانات المرتبة (زي 1-2-3 أو درجات الحرارة)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 110445.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# تدرج الألوان حسب القيمة

# %% [markdown]
# #### ↔️ Diverging	لما فيه نقطة مركزية (زي "محايد" بين إيجابي وسلبي)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 110716.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Plotting many variables at once

# %% [markdown]
# 🎯 1. الهدف من الدرس
#
# إزاي نرسم ونفهم علاقات بين عدد كبير من المتغيرات؟
#
# هنستخدم:
#
# ✅ Pair plots
#
# ✅ Correlation heatmaps
#
# ✅ Parallel coordinates plots

# %% [markdown]
# ### 🔗 2. **Pair Plots** – إمتى تستخدمها؟
#
# ممتازة لو عندك حوالي 10 متغيرات أو أقل
#
# العلاقة بين كل زوج من المتغيرات
#
# القطر (Diagonal):
#
# متغير تصنيفي → bar plot
#
# متغير رقمي → histogram
#
# خارج القطر (Off-diagonal):
#
# رقمي × رقمي → scatter plot + معامل ارتباط correlation
#
# رقمي × تصنيفي → box plot و histogram متقطعة حسب الفئة

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 143024.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 🧭 7. **Correlation Heatmaps** – إمتى تستخدمها؟
#
# لو كل المتغيرات رقمية وعايز تشوف العلاقة بين كل زوج بسرعة:
#
# ✅ أسهل من الـ pair plot
#
# ✅ تنفع مع عدد كبير جدًا من المتغيرات
#
# كل خانة → لون يدل على درجة الارتباط بين متغيرين
#
# الأحمر الفاتح = ارتباط موجب قوي
#
# الأزرق = ارتباط سالب
#
# الأبيض = لا يوجد ارتباط
#
# 🧪 مثال عملي:
# استبيان رضا العملاء → الميزات المتعلقة بالسعر كانت مرتبطة ببعض بقوة

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 143514.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🧮 9. Scatter Plot مش هينفع لو زاد عدد المتغيرات
#
# لو عندك 4 متغيرات أو أكتر، scatter plot بيبدأ يبقى معقد جدًا
#
# → الحل الأفضل: parallel coordinates plot

# %% [markdown]
# ### 🧬 10. **Parallel Coordinates** – إمتى تستخدمها؟
#
# ✅ عندك عدد كبير من المتغيرات الرقمية
#
# ✅ عايز تشوف علاقات، أنماط أو تجميعات (Clusters)
#
# كل متغير → محور رأسي
#
# كل صف (بلد مثلًا) → خط
#
# بيعرض قيم المتغيرات كلها في خط واحد
#
# المحاور تكون مقيّسة (scaled)
#
# ⚠️ المشكلة: لو البيانات معقدة جدًا، الرسم بيبقى زحمة ومش واضح
#
# → جرب تقسيم البيانات حسب قارة مثلاً

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 143659.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 143808.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# # **99 problems but a plot ain't one of them**

# %% [markdown]
# ## **Polar coordinates**

# %% [markdown]
# 🧭 1–2. المقدمة: فين الباي شارت؟
#
# طول الكورس ما اتكلمناش عن Pie Charts، رغم إنها من أكثر الرسومات البيانية شهرة!
#
# ❌ السبب: رغم شهرتها، فهي صعبة التفسير وغير دقيقة في نقل المعلومة مقارنةً بـ Bar Plots.

# %% [markdown]
# **📊 3–4. الباي شارت = بار شارت بدائرة**
#
# عندك Bar Plot لعدد الرياضيين المشاهير حسب الرياضة (كرة، كريكت، إلخ)
#
# لو غيرت المحاور من Cartesian إلى Polar ← يتحول الرسم إلى Pie Chart
# (زوايا تمثل النسب بدل أطوال الأعمدة)
#
# 🎯 النتيجة: شكل لطيف لكن...
#
# من الصعب جدًا تقدير الفرق بين الأقسام
#
# سؤال بسيط زي: "كام لاعب كريكت؟" بيبقى غامض
#
# 🔬 الأبحاث بتأكد إن البار شارت أسهل قراءة بـفرق كبير.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 161204.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 161225.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ❓ 5. امتى تستخدم Polar Coordinates؟
#
# استخدامها نادر جدًا، إلا في حالة واحدة:
#
# ✅ لما البيانات نفسها دائرية طبيعيًا، زي:
#
# الوقت خلال اليوم ⏰
#
# الاتجاهات الجغرافية (شمال، جنوب…) 🧭

# %% [markdown]
# ### Rose Plot
#
# يمثل المتغير نفسه (الوقت مثلاً)
#
# متغير حسب القيمة (activity)
#
# تحليل دوراني/زمني
#
# ### Pie Plot
#
# يمثل النسبة (حجم الفئة)
#
# ثابت (يعتمد على الزاوية)
#
# توزيع فئات

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 161355.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 161514.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ##  Axes of Evil

# %% [markdown]
# كيف يمكن للمحاور أن تضلل وتفسد المعنى الحقيقي للبيانات؟

# %% [markdown]
# 📏 1–2. مشكلة أطوال الأعمدة الغير منطقية (Nonsense Bar Lengths)
#
# في الرسوم البيانية بالأعمدة، الطول = القيمة!
#
# لو عدلت الطول بشكل غير متناسب مع الرقم، بتضلل القارئ.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 180230.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🧱 3. نفس المشكلة في Stacked Bar Plots
#
# 📊 مثال تاني:
#
# رسم بياني لحصة أنظمة تشغيل الهواتف
#
# المحور الرأسي (y-axis) بدأ من 75% مش من 0%!
#
# النتيجة؟ iOS و Android يبانوا متساويين تقريبًا، رغم إن Android أكبر بكتير!
#
# 🎯 الدرس:
# ابدأ الـ y-axis من الصفر، خصوصًا لما يكون المطلوب إبراز "النسبة من الكل".

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 180528.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# 🧯 4. المحاور الثنائية (Dual Axes) = خطر كبير
#
# 📍 المثال:
#
# UN dataset: المحور الأفقي = سنوات التعليم
#
# المحور الأيسر = متوسط العمر (Life Expectancy)
#
# المحور الأيمن = Human Development Index (من 0 إلى 1)
#
# 🎯 المشكلة:
#
# ممكن تعديل المحور الأيمن يخلي العلاقة باينة أو غير باينة حسب مزاجك!
#
# ممكن الناس تفهم إن فيه علاقة قوية (أو مفيش علاقة) لمجرد إن الـ scale مختلف
#
# 🧠 النتيجة: لازم تبص كويس قوي على المحاور عشان تفهم... وده ضد مبدأ الـ clarity في الـ data viz.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 181232.png")

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread(r"C:\Users\USER\OneDrive - Mansoura University - Main\Pictures\Statistics\Screenshot 2025-07-11 181252.png")

plt.imshow(img)
plt.axis('off')
plt.show()
