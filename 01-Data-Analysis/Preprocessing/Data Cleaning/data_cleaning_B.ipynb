# %% [markdown]
# #  🧹 **Data Cleaning and Preparation**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1️⃣ 7.1 ❌ Handling Missing Data**

# %% [markdown]
# ## **🔍 Detect missing values**

# %% [markdown]
# ### **.isna( )**

# %%
float_data = pd.Series([1.2, -3.5, np.nan, 0])
print(float_data.isna())  # isna() → يرجع Boolean Series: True للمفقود.
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# ### **.notna( )**

# %%
string_data = pd.Series(["aardvark", np.nan, None, "avocado"])
print(string_data.notna())     # # notna() → يرجع Boolean Series: False للمفقود.
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# dtype: bool

# %% [markdown]
# ## **🗑 Filtering Out Missing Data**

# %% [markdown]
# ### **on Series**
# dropna() → يحذف العناصر اللي فيها NA.
#
# data[data.notna()] → نفس النتيجة لكن باستخدام

# %%
data = pd.Series([1, np.nan, 3.5, np.nan, 7])
print(data.dropna())
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
print(data[data.notna()])
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %% [markdown]
# ### **on DataFram**
#
# dropna() → يحذف أي صف فيه قيمة مفقودة.
#
# dropna(how="all") → يحذف الصفوف اللي كلها NA.
#
# dropna(how="any") →  يحذف الصفوف اللي فيها قيمة واحد مفقوده ع الاقل .
#
# dropna(axis="columns") → يحذف الأعمدة اللي كلها NA.
#
# dropna(thresh=n) → يحتفظ بالصفوف اللي فيها على الأقل n قيم مش مفقودة.

# %%
df = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                   [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])
print(df.dropna())              # يحذف الصفوف اللي فيها NA
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
print(df.dropna(how="all"))    # يحذف الصفوف الفاضية بالكامل
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
print(df.dropna(axis="columns", how="all")) # يحذف الأعمدة الفاضية بالكامل
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %% [markdown]
# ## **🩹 Filling Missing Data**

# %% [markdown]
# ffill(limit=2)### **🔹 fillna()**
#
# fillna(value) → يملأ الـ NA بقيمة ثابتة.
#
# fillna({col1: val1, col2: val2}) → يملأ كل عمود بقيمة مختلفة.
#
# ffill(limit=num) → يملأ بالقيمة السابقة (Forward Fill).
#
# bfill(limit=num)  → يملأ بالقيمة اللاحقة (Backward Fill).
#
# fillna(data.mean()) → تعويض القيم بالمتوسط أو أي إحصائية.
#
# limit → يحدد عدد القيم اللي يتم تعويضها بشكل متتالي.

# %%
df = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                   [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])

# %%
df.fillna(0)
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  0.0  0.0
# 2  0.0  0.0  0.0
# 3  0.0  6.5  3.0

# %%
df.fillna(df.mean())
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  1.0  6.5  3.0
# 3  1.0  6.5  3.0

# %%
df.fillna({0: -1, 1: 0.5, 2:0})
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  0.5  0.0
# 2 -1.0  0.5  0.0
# 3 -1.0  6.5  3.0

# %%
df.ffill(limit=2)

 # df.fillna(method="ffill", limit=2) قديمة
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  1.0  6.5  3.0
# 3  1.0  6.5  3.0

# %% [markdown]
# # **2️⃣ 7.2 Data Transformation**

# %% [markdown]
# ## **1️⃣ Removing Duplicates**

# %% [markdown]
# duplicated() → يديك Boolean Series يوضح إذا كان الصف مكرر أم لا.
#
# drop_duplicates() → يحذف الصفوف المكررة.
#
# تقدر تحدد subset (أعمدة معينة) للفحص.
#
# باستخدام keep="last" ممكن تحتفظ بآخر تكرار بدل الأول.

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"],
                     "k2": [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
data.drop_duplicates(subset=["k1"])   # حذف كل القيم المكرره من العمود K1
# Out:
#     k1  k2
# 0  one   1
# 1  two   1

# %%
data.drop_duplicates(["k1", "k2"], keep="last")
# احذف الكيم اللي تتكرر في K1 and K2 مع بعض سيب اخر نسخه
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 6  two   4

# %% [markdown]
# ## **2️⃣ Transforming Data Using Function or Mapping**

# %% [markdown]
# map(dictionary)
#
#  map(function)

# %%
data = pd.DataFrame({"food": ["bacon", "pulled pork", "bacon",
                              "pastrami", "corned beef", "bacon",
                              "pastrami", "honey ham", "nova lox"],
                    "ounces": [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     pastrami     6.0
# 4  corned beef     7.5
# 5        bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {"bacon": "pig", "pulled pork": "pig",
                  "pastrami": "cow", "corned beef": "cow",
                  "honey ham": "pig", "nova lox": "salmon"}

data["animal"] = data["food"].map(meat_to_animal)
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %% [markdown]
# ## **3️⃣ Replacing Values**

# %% [markdown]
# ### **.replace()**
#
# تبدل قيمة واحدة.
#
# تبدل قائمة قيم بنفس القيمة.
#
# تبدل قيم متعددة بقيم مختلفة (list أو dict).

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
data.replace({-999: np.nan, -1000: 0})
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %% [markdown]
# ## **4️⃣ Renaming Axis Indexes**

# %% [markdown]
# ممكن نغير أسماء الصفوف والأعمدة باستخدام:
#
# **map()** على الـ index أو الـ columns.
#
# **rename()** عشان ما تعدلش الـ DataFrame الأصلي.

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
                    index=["Ohio", "Colorado", "New York"],
                    columns=["one", "two", "three", "four"])

data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.rename(index={"Ohio": "INDIANA"}, columns={"three": "peekaboo"})
# Out:
#           one  two  peekaboo  four
# INDIANA     0    1         2     3
# Colorado    4    5         6     7
# New York    8    9        10    11

# %%
data.rename(index=str.title, columns=str.upper)
# Out:
#           ONE  TWO  THREE  FOUR
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
def transform(x):
   return x[:4].upper()

data.index = data.index.map(transform)
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %% [markdown]
# ## **5️⃣ Discretization and Binning**

# %% [markdown]
# ### **(Bins)**
#
# لو عندك بيانات مستمرة (زي الأعمار أو الدخل)، ممكن تقسّمها لفئات.
#
# ### pd.cut()
#  → تقسيم حسب حدود bins.
#
# ### pd.qcut()
# → تقسيم حسب quantiles (الفئات متساوية الحجم تقريبًا).

# %% [markdown]
# | الوظيفة     | طريقة التقسيم                          | مناسب متى؟                                        |
# | ----------- | -------------------------------------- | ------------------------------------------------- |
# | `pd.cut()`  | تقسيم حسب **حدود أنت بتحددها**         | لما يكون عندك معنى منطقي للفئات (زي أعمار محددة). |
# | `pd.qcut()` | تقسيم حسب **Quantiles (متساوي العدد)** | لما تحب الفئات كلها تبقى متوازنة في الحجم.        |

# %% [markdown]
# ### **📌 الفكرة الأساسية:**
#
# لو عندك بيانات مستمرة Continuous (زي العمر، الطول، الوزن، الدخل)، ساعات بيكون مفيد إننا نحوّلها لفئات Categories.
#
# وده اسمه Binning أو Discretization.

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
bins = [18, 25, 35, 60, 100]

categories = pd.cut(ages, bins)
print(categories)
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
categories = pd.cut(ages, bins, labels=["Youth", "YoungAdult", "MiddleAged", "Senior"])
categories
# Out:
# ['Youth', 'Youth', 'Youth', 'YoungAdult', 'Youth', ..., 'YoungAdult', 'Senior', 'MiddleAged', 'MiddleAged', 'YoungAdult']
# Length: 12
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']

# %% [markdown]
# ### **الشرح:**
#
# 18–25 → Youth
#
# 25–35 → YoungAdult
#
# 35–60 → MiddleAged
#
# 60–100 → Senior

# %%
data = [7, 2, 5, 9, 10, 15, 1, 20, 25, 30]
qcut_result = pd.qcut(data, 4, labels=["Q1", "Q2", "Q3", "Q4"])
qcut_result
# Out:
# ['Q2', 'Q1', 'Q1', 'Q2', 'Q3', 'Q3', 'Q1', 'Q4', 'Q4', 'Q4']
# Categories (4, object): ['Q1' < 'Q2' < 'Q3' < 'Q4']

# %% [markdown]
# ## **6️⃣ Detecting and Filtering Outliers**

# %%
# بيانات عشوائية
import pandas as pd
import numpy as np
rng = np.random.default_rng(seed=12345)
data = rng.standard_normal((1000, 4))
df = pd.DataFrame(data)
df
# Out:
#             0         1         2         3
# 0   -1.423825  1.263728 -0.870662 -0.259173
# 1   -0.075343 -0.740885 -1.367793  0.648893
# 2    0.361058 -1.952863  2.347410  0.968497
# 3   -0.759387  0.902198 -0.466953 -0.060690
# 4    0.788844 -1.256668  0.575858  1.398979
# ..        ...       ...       ...       ...
# 995  0.882424  0.117986 -1.594591  0.617857
# 996  0.426579 -0.349593 -0.912300 -0.607779
# 997 -1.824397 -0.545148 -0.618174 -1.071964
# 998 -0.479874 -1.752196  0.989474 -0.317403
# 999 -1.351867  0.620931  0.405851 -0.662979
#
# [1000 rows x 4 columns]

# %%
df.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.041958    -0.019989     0.005112     0.078280
# std       0.967856     0.993715     1.015471     1.053955
# min      -2.736509    -3.414646    -3.119609    -2.874133
# 25%      -0.655281    -0.665431    -0.689012    -0.672366
# 50%      -0.069287    -0.041196    -0.029181     0.061795
# 75%       0.621099     0.612585     0.725447     0.787001
# max       3.200689     3.461976     3.721098     3.378876

# %%
# الصفوف اللي فيها قيم أكبر من 3 أو أقل من -3
outliers = data[(df.abs() > 3).any(axis="columns")]
# لو  اي عمود في الصف outlier الصف كله بيتحدد انه بيحتوي ع outlier
outliers
# Out:
# array([[-0.55599901,  1.35638101, -3.11960863, -1.4476717 ],
#        [ 3.20068942,  2.14788244, -0.10666477, -0.93015494],
#        [-0.32368662,  0.5746962 ,  3.21141765, -1.78846554],
#        [-0.15004013,  0.38989694, -1.08308193,  3.08547984],
#        [ 0.90096505,  3.46197581, -0.28949683,  1.22068709],
#        [ 0.81724062,  0.10800997,  0.34199802,  3.14545143],
#        [-0.53853982,  1.08087294,  0.31182729,  3.04165289],
#        [ 1.75654852,  1.10627131,  3.72109781, -1.39177304],
#        [ 0.63546921,  2.31984638, -3.08212823, -1.12760431],
#        [-0.94401886, -2.10384273,  0.56215108,  3.37887608],
#        [-0.2739689 ,  0.01372584,  0.06266693,  3.11003849],
#        [ 0.16287571, -3.41464583, -1.35519652,  0.74319743]])

# %%
# استبدال القيم المتطرفة بـ +3 أو -3
df[df.abs() > 3] = np.sign(data) * 3
outliers_2 = data[(df.abs() > 3).any(axis="columns")]
outliers_2
# Out:
# array([], shape=(0, 4), dtype=float64)

# %% [markdown]
# ## **7️⃣ 🎲 Permutation and Random Sampling**

# %%
df = pd.DataFrame(np.arange(40).reshape(10, 4))

# %%
print(df.sample(n=3))           # 3 صفوف عشوائية
# Out:
#     0   1   2   3
# 6  24  25  26  27
# 2   8   9  10  11
# 0   0   1   2   3

# %%
print(df.sample(n=5, replace=True))      # 5 صفوف مع تكرار
# Out:
#     0   1   2   3
# 5  20  21  22  23
# 5  20  21  22  23
# 0   0   1   2   3
# 7  28  29  30  31
# 6  24  25  26  27

# %% [markdown]
# ## **8️⃣ 🎭 Indicator/Dummy Variables**

# %% [markdown]
# ### **المتغيرات الوهمية (One-Hot Encoding)**

# %% [markdown]
# ### 📌 يعني إيه؟
#
# لو عندك عمود فيه قيم نصية (categorical) زي: ["cat", "dog", "bird"]، الكمبيوتر مايفهمهاش بسهولة في Machine Learning.
#
# فـ الدوال الوهمية (Dummy Variables) بتحول كل قيمة لعمود جديد (0/1).
#
# 1 = الصف ينتمي للقيمة دي.
#
# 0 = الصف مش ينتمي.

# %%
df = pd.DataFrame({"key": ["b", "b", "a", "c", "a", "b"], "data1": range(6)})
df
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   b      5

# %%
# تحويل عمود key إلى أعمدة 0/1
dummies = pd.get_dummies(df["key"], prefix="key", dtype=float)

# دمج الداتا الأصلية مع الأعمدة الجديدة
df_with_dummy = df.join(dummies)
print(df_with_dummy)

# %% [markdown]
# # **3️⃣ 7.3 Extension Data Types**

# %% [markdown]
# | الفئة                                                    | المشكلة في NumPy                              | تأثيرها في Pandas                                                                       | الحل (Extension Dtypes)                                                  |
# | -------------------------------------------------------- | --------------------------------------------- | --------------------------------------------------------------------------------------- | ------------------------------------------------------------------------ |
# | **الأعداد الصحيحة (Integers) + Booleans**                | مفيش دعم للقيم المفقودة                       | Pandas يغيّر العمود تلقائيًا لـ **float64** ويحط `np.nan` → يعمل مشاكل خفية في الحسابات | دعم نوع جديد زي `Int64Dtype` و `BooleanDtype` اللي بيسمح بالقيم المفقودة |
# | **النصوص (Strings)**                                     | تخزين بطيء + استهلاك كبير للذاكرة             | الأداء ضعيف جدًا في معالجة النصوص                                                       | نوع جديد `StringDtype` أسرع وأكفأ                                        |
# | **أنواع البيانات الخاصة** (تواريخ، فروق زمنية، Timezone) | لازم تتخزن كـ **Python objects** → بطيء ومكلف | بطء في العمليات الحسابية والتخزين                                                       | أنواع بيانات خاصة زي `Categorical`, `Period`, `DatetimeTZDtype`          |

# %%
import pandas as pd
# Series من Integers فيها Missing Value
s = pd.Series([1, 2, 3, None])
print(s)
print(s.dtype)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64
# float64

# %% [markdown]
# Pandas هنا حوّل الـ integers إلى float64.
#
# السبب: علشان يعرف يحط NaN.
#
# ### **🟠 الحل باستخدام Int64Dtype**

# %%
s = pd.Series([1, 2, 3, None], dtype=pd.Int64Dtype())
print(s)                   # "Int64" =  pd.Int64Dtype()
print(s.dtype)
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# dtype: Int64
# Int64

# %%
print(s.isna())
print(s[3] is pd.NA)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool
# True

# %%
s = pd.Series(['one', 'two', None, 'three'], dtype=pd.StringDtype())
print(s)
# Out:
# 0      one
# 1      two
# 2     <NA>
# 3    three
# dtype: string

# %% [markdown]
# ### **🟢 تحويل الأعمدة باستخدام astype()**

# %%
df = pd.DataFrame({
    "A": [1, 2, None, 4],
    "B": ["one", "two", "three", None],
    "C": [False, None, False, True]
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       3 non-null      object
#  2   C       3 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df["A"] = df["A"].astype("Int64")
df["B"] = df["B"].astype("string")
df["C"] = df["C"].astype("boolean")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      Int64
#  1   B       3 non-null      string
#  2   C       3 non-null      boolean
# dtypes: Int64(1), boolean(1), string(1)
# memory usage: 208.0 bytes

# %%
df
# Out:
#       A      B      C
# 0     1    one  False
# 1     2    two   <NA>
# 2  <NA>  three  False
# 3     4   <NA>   True

# %% [markdown]
# | النوع                             | الوصف                              |
# | --------------------------------- | ---------------------------------- |
# | **boolean**                       | Boolean يدعم القيم المفقودة        |
# | **category**                      | بيانات تصنيفية (Categorical)       |
# | **datetime64\[ns, tz]**           | تاريخ/وقت مع منطقة زمنية           |
# | **Float32, Float64**              | Floats مع دعم القيم المفقودة       |
# | **Int8, Int16, Int32, Int64**     | Integers بإمكانية وجود NA          |
# | **UInt8, UInt16, UInt32, UInt64** | Unsigned integers بإمكانية وجود NA |
# | **string**                        | نصوص مع دعم القيم المفقودة         |

# %% [markdown]
# # **4️⃣ 7.4 String Manipulation**

# %% [markdown]
# # **5️⃣ 7.5 Categorical Data**
